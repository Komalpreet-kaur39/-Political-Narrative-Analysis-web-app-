# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **NDTV**

# %%
df_n1 = pd.read_csv("data/insights/title_desc_cap/en_NDTV_insights_tdc.csv")

# %%
# Calculate the counts of each target party
target_party_counts = df_n['Target Party'].value_counts()

# Define a threshold for grouping small proportions into "Other"
threshold = 0.02 * target_party_counts.sum()  # 2% threshold
target_party_counts = target_party_counts[target_party_counts >= threshold]
other_count = df_n['Target Party'].value_counts()[df_n['Target Party'].value_counts() < threshold].sum()

# Add the "Other" category if needed
if other_count > 0:
    target_party_counts['Other'] = other_count

# Calculate the proportions
target_party_proportions = target_party_counts / target_party_counts.sum()

# Plot the pie chart
colors = ['#f97d09','#02478E','#167B37','#B02C28']
plt.figure(figsize=(10, 7), facecolor='none')  
plt.pie(
    target_party_proportions,
    labels=target_party_proportions.index,
    autopct='%1.1f%%',
    startangle=140,
    textprops={'color': 'white'} ,
    colors=colors[:len(target_party_proportions)] 
)
plt.title('Party Mentions in the Videos', color='white')  
plt.gca().set_facecolor('none')
plt.savefig('images/en_ndtv_images/counts of each party.png')

# %%
import matplotlib.pyplot as plt

# Calculate the total count for each party
party_counts = df_n['Target Party'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_n[df_n['Target Party'].isin(filtered_parties)]

# Group the data by Target Party and Sentiment and get counts
sentiment_counts = filtered_df.groupby(['Target Party', 'Sentiment']).size().unstack(fill_value=0)

# Sort the sentiment counts by the sum of counts for each party
sentiment_counts = sentiment_counts.loc[sentiment_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the sorted stacked horizontal bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
sentiment_counts.plot(kind='barh', stacked=True, ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', (p.get_x() + p.get_width() / 2, p.get_y() + p.get_height() / 2),
                ha='center', va='center', color='white', fontsize=10)

# Set plot title and labels with white color
plt.title('Sentiment Counts for Each Target Party', color='white')
plt.xlabel('Count', color='white')
plt.ylabel('Target Party', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/en_ndtv_images/sentiment counts of each party.png')

# Show the plot
plt.show()

# %%
# Calculate the total count for each party
party_counts = df_n['Target Party'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_n[df_n['Target Party'].isin(filtered_parties)]

# Group the data by Target Party and Orientation and get counts
orientation_counts = filtered_df.groupby(['Target Party', 'Orientation']).size().unstack(fill_value=0)

# Sort the orientation counts by the sum of counts for each party
orientation_counts = orientation_counts.loc[orientation_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the grouped bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
orientation_counts.plot(kind='bar', ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_y() + p.get_height() / 2),
                ha='center', va='center', color='white', fontsize=7)

# Set plot title and labels with white color
plt.title('Orientation Counts for Each Target Party', color='white')
plt.xlabel('Target Party', color='white')
plt.ylabel('Count', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/en_ndtv_images/orientation counts of each party.png')

# Show the plot
plt.show()

# %%
# Calculate the counts of each alliance
alliance_counts = df_n['Alliance'].value_counts()

# Define a threshold for grouping small proportions into "Other"
threshold = 0.02 * alliance_counts.sum()  # 2% threshold
alliance_counts = alliance_counts[alliance_counts >= threshold]
other_count = df_n['Alliance'].value_counts()[df_n['Alliance'].value_counts() < threshold].sum()

# Add the "Other" category if needed
if other_count > 0:
    alliance_counts['Other'] = other_count

# Calculate the proportions
alliance_proportions = alliance_counts / alliance_counts.sum()

# Plot the pie chart
colors = ['#f97d09', '#02478E', '#B02C28', '#B02C28']
plt.figure(figsize=(10, 7), facecolor='none')
plt.pie(
    alliance_proportions,
    labels=alliance_proportions.index,
    autopct='%1.1f%%',
    startangle=140,
    textprops={'color': 'white'},
    colors=colors[:len(alliance_proportions)]
)
plt.title('Alliance Mentions in the Videos', color='white')
plt.gca().set_facecolor('none')

plt.savefig('images/en_ndtv_images/counts of each alliance.png')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the total count for each party
party_counts = df_n['Alliance'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_n[df_n['Alliance'].isin(filtered_parties)]

# Group the data by Alliance and Sentiment and get counts
sentiment_counts = filtered_df.groupby(['Alliance', 'Sentiment']).size().unstack(fill_value=0)

# Sort the sentiment counts by the sum of counts for each party
sentiment_counts = sentiment_counts.loc[sentiment_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the sorted stacked horizontal bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
sentiment_counts.plot(kind='barh', stacked=True, ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', (p.get_x() + p.get_width() / 2, p.get_y() + p.get_height() / 2),
                ha='center', va='center', color='white', fontsize=10)

# Set plot title and labels with white color
plt.title('Sentiment Counts for Each Alliance', color='white')
plt.xlabel('Count', color='white')
plt.ylabel('Alliance', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/en_ndtv_images/sentiment counts of each alliance.png')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the total count for each party
party_counts = df_n['Alliance'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_n[df_n['Alliance'].isin(filtered_parties)]

# Group the data by Target Party and Orientation and get counts
orientation_counts = filtered_df.groupby(['Alliance', 'Orientation']).size().unstack(fill_value=0)

# Sort the orientation counts by the sum of counts for each party
orientation_counts = orientation_counts.loc[orientation_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the vertical bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
orientation_counts.plot(kind='bar', ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_height() + 0.5),
                ha='center', va='bottom', color='white', fontsize=7)

# Set plot title and labels with white color
plt.title('Orientation Counts for Alliance', color='white')
plt.xlabel('Alliance', color='white')
plt.ylabel('Count', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/en_ndtv_images/orientation counts of each alliance.png')

# Show the plot
plt.show()

# %%
# Define thresholds
views_threshold = 150000

# Filter parties above the threshold
filtered_views = df_n.groupby('Target Party')['views'].sum()

# Create 'Others' category for views
views_below_threshold = filtered_views[filtered_views < views_threshold].sum()
filtered_views = filtered_views[filtered_views >= views_threshold]
filtered_views['Others'] = views_below_threshold

# Sort the views in descending order
filtered_views = filtered_views.sort_values(ascending=True)

# Plot the chart
fig, ax = plt.subplots(figsize=(15, 7), facecolor='none')

# Plot total views
ax.barh(filtered_views.index, filtered_views.values, color='coral')
ax.set_xlabel('Total Views', color='white')
ax.set_ylabel('Target Party', color='white')
ax.set_title('Total Views per Target Party', color='white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Annotate the bars with integer counts for views
for i in ax.patches:
    ax.annotate(f'{int(i.get_width())}', (i.get_width() + i.get_x(), i.get_y() + i.get_height() / 2),
                ha='left', va='center', color='white', fontsize=7)

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/en_ndtv_images/total view.png')

plt.tight_layout()
plt.show()

# %%
# Ensure the 'publish_date' column is in datetime format
df_n.loc[:, 'publish_date'] = pd.to_datetime(df_n['publish_date'], format='%d-%m-%Y')

# Define custom colors for the parties
party_colors = {
    'BJP': '#f97d09',
    'INC': '#02478E',
    'AAP': '#167B37', 
}

# Function to plot the timeline for a given orientation
def plot_timeline(orientation, title, ax, threshold, party_colors):
    # Filter for rows where Orientation matches the specified orientation
    df_orientation = df_n[df_n['Orientation'] == orientation]

    # Define the threshold and filter out parties below the threshold
    party_counts = df_orientation['Target Party'].value_counts()
    filtered_parties = party_counts[party_counts >= threshold].index
    df_orientation = df_orientation[df_orientation['Target Party'].isin(filtered_parties)]

    # Group the data by publish_date and Target Party to get the count of sentiments
    grouped_df = df_orientation.groupby(['publish_date', 'Target Party']).size().unstack(level=1, fill_value=0)

    # Plot the timeline for each party with custom colors
    colors = [party_colors.get(col, '#333333') for col in grouped_df.columns]
    grouped_df.plot(ax=ax, linestyle='-', color=colors)

    # Set labels with white color
    ax.set_xlabel('Date', color='white')
    ax.set_ylabel('Count', color='white')
    ax.set_title(title, color='white')

    # Set x and y axis tick parameters to white
    ax.tick_params(axis='x', colors='white')
    ax.tick_params(axis='y', colors='white')

    # Set the figure background and axes face color to transparent
    fig.patch.set_alpha(0.0)
    ax.patch.set_alpha(0.0)

    # Set the border color of the plot to white
    ax.spines['top'].set_color('white')
    ax.spines['right'].set_color('white')
    ax.spines['bottom'].set_color('white')
    ax.spines['left'].set_color('white')

# Define thresholds
threshold_supports = 10
threshold_opposes = 30

# Create a plot for 'Supports' and 'Opposes' sentiments side by side
fig, axes = plt.subplots(1, 2, figsize=(15, 7), sharey=True)

# Plot for 'Supports' sentiment
plot_timeline('Supports', 'Timeline of Supportive Sentiments by Party', axes[0], threshold_supports, party_colors)

# Plot for 'Opposes' sentiment
plot_timeline('Opposes', 'Timeline of Opposing Sentiments by Party', axes[1], threshold_opposes, party_colors)

plt.tight_layout()
plt.savefig('images/en_ndtv_images/timeline sentiment.png')

plt.show()

# %%
# Drop rows where 'publish_date', 'Orientation' or 'Target Party' is NaN
df = df_n.dropna(subset=['publish_date', 'Orientation', 'Target Party'])

# Convert 'publish_date' to datetime
df['publish_date'] = pd.to_datetime(df['publish_date'])

# Define the phases and their dates
phases = {
    'Phase 01': '2024-04-19',
    'Phase 02': '2024-04-26',
    'Phase 03': '2024-05-07',
    'Phase 04': '2024-05-13',
    'Phase 05': '2024-05-20',
    'Phase 06': '2024-05-25',
    'Phase 07': '2024-06-01'
}

# Add a phase column to the dataframe
def assign_phase(date):
    for phase, phase_date in phases.items():
        if date <= pd.to_datetime(phase_date):
            return phase
    return 'Phase 07'

df['Phase'] = df['publish_date'].apply(assign_phase)

# Group by 'Phase' and 'Target Party' and count the occurrences for each orientation
supports_counts = df[df['Orientation'] == 'Supports'].groupby(['Phase', 'Target Party']).size().unstack(fill_value=0)
opposes_counts = df[df['Orientation'] == 'Opposes'].groupby(['Phase', 'Target Party']).size().unstack(fill_value=0)

# Define a threshold to show only the top parties
threshold = 10

# Filter the parties based on the threshold
top_supports_parties = supports_counts.columns[supports_counts.sum() > threshold]
top_opposes_parties = opposes_counts.columns[opposes_counts.sum() > threshold]

supports_counts = supports_counts[top_supports_parties]
opposes_counts = opposes_counts[top_opposes_parties]

# Define custom colors for the parties
party_colors = {
    'BJP': '#f97d09',
    'INC': '#02478E',
    'AAP': '#167B37', 
}

# Plot the horizontal bar charts side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 10), sharey=True)

# Set transparent background
fig.patch.set_alpha(0)
for ax in axes:
    ax.patch.set_alpha(0)

# Plot the supports chart
supports_counts.plot(kind='barh', stacked=False, ax=axes[0], color=[party_colors.get(col, '#333333') for col in supports_counts.columns])
axes[0].set_title('Supports', color='white')
axes[0].set_xlabel('Counts', color='white')
axes[0].set_ylabel('Phase', color='white')
axes[0].legend(title='Target Party', facecolor='white', edgecolor='white', labelcolor='black')

# Plot the opposes chart
opposes_counts.plot(kind='barh', stacked=False, ax=axes[1], color=[party_colors.get(col, '#333333') for col in opposes_counts.columns])
axes[1].set_title('Opposes', color='white')
axes[1].set_xlabel('Counts', color='white')
axes[1].set_ylabel('', color='white')

# Set white text and border for both axes
for ax in axes:
    ax.title.set_color('white')
    ax.xaxis.label.set_color('white')
    ax.yaxis.label.set_color('white')
    ax.spines['bottom'].set_color('white')
    ax.spines['top'].set_color('white')
    ax.spines['right'].set_color('white')
    ax.spines['left'].set_color('white')
    ax.tick_params(axis='x', colors='white')
    ax.tick_params(axis='y', colors='white')
    for label in ax.get_yticklabels():
        label.set_color('white')
    for label in ax.get_xticklabels():
        label.set_color('white')

plt.suptitle('Party-wise Sentiment Counts Across Election Phases', color='white')
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# /tmp/ipykernel_64972/3389088570.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['publish_date'] = pd.to_datetime(df['publish_date'])
# /tmp/ipykernel_64972/3389088570.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phase'] = df['publish_date'].apply(assign_phase)

# %%
import matplotlib.pyplot as plt

# Drop rows where 'publish_date', 'Orientation' or 'Target Party' is NaN
df = df_n.dropna(subset=['publish_date', 'Orientation', 'Target Party'])

# Convert 'publish_date' to datetime
df['publish_date'] = pd.to_datetime(df['publish_date'],dayfirst=True)

# Define the phases and their dates
phases = {
    'Phase 01': '2024-04-19',
    'Phase 02': '2024-04-26',
    'Phase 03': '2024-05-07',
    'Phase 04': '2024-05-13',
    'Phase 05': '2024-05-20',
    'Phase 06': '2024-05-25',
    'Phase 07': '2024-06-01'
}

# Add a phase column to the dataframe
def assign_phase(date):
    for phase, phase_date in phases.items():
        if date <= pd.to_datetime(phase_date):
            return phase
    return 'Phase 07'

df['Phase'] = df['publish_date'].apply(assign_phase)

# Group by 'Phase' and 'Target Party' and count the occurrences for each orientation
supports_counts = df[df['Orientation'] == 'Supports'].groupby(['Phase', 'Target Party']).size().unstack(fill_value=0)
opposes_counts = df[df['Orientation'] == 'Opposes'].groupby(['Phase', 'Target Party']).size().unstack(fill_value=0)

# Define a threshold to show only the top parties
threshold = 10

# Filter the parties based on the threshold
top_supports_parties = supports_counts.columns[supports_counts.sum() > threshold]
top_opposes_parties = opposes_counts.columns[opposes_counts.sum() > threshold]

supports_counts = supports_counts[top_supports_parties]
opposes_counts = opposes_counts[top_opposes_parties]

# Define custom colors for the parties
party_colors = {
    'BJP': '#f97d09',
    'INC': '#02478E',
    'AAP': '#167B37',
}

# Plot the line charts side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 10), sharey=True)

# Set transparent background
fig.patch.set_alpha(0)
for ax in axes:
    ax.patch.set_alpha(0)

# Plot the supports chart
for party in supports_counts.columns:
    axes[0].plot(supports_counts.index, supports_counts[party], marker='o', color=party_colors.get(party, '#333333'), label=party)
axes[0].set_title('Supports', color='white')
axes[0].set_xlabel('Phase', color='white')
axes[0].set_ylabel('Counts', color='white')
axes[0].legend(title='Target Party', facecolor='white', edgecolor='white', labelcolor='black')

# Plot the opposes chart
for party in opposes_counts.columns:
    axes[1].plot(opposes_counts.index, opposes_counts[party], marker='o', color=party_colors.get(party, '#333333'), label=party)
axes[1].set_title('Opposes', color='white')
axes[1].set_xlabel('Phase', color='white')
axes[1].set_ylabel('', color='white')

# Set white text and border for both axes
for ax in axes:
    ax.title.set_color('white')
    ax.xaxis.label.set_color('white')
    ax.yaxis.label.set_color('white')
    ax.spines['bottom'].set_color('white')
    ax.spines['top'].set_color('white')
    ax.spines['right'].set_color('white')
    ax.spines['left'].set_color('white')
    ax.tick_params(axis='x', colors='white')
    ax.tick_params(axis='y', colors='white')
    for label in ax.get_yticklabels():
        label.set_color('white')
    for label in ax.get_xticklabels():
        label.set_color('white')

plt.suptitle('Party-wise Sentiment Counts Across Election Phases', color='white')
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# /tmp/ipykernel_5022/83946199.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['publish_date'] = pd.to_datetime(df['publish_date'],dayfirst=True)
# /tmp/ipykernel_5022/83946199.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phase'] = df['publish_date'].apply(assign_phase)

# %%
# Define colors for the pie chart
bias_colors = {
    'Yes': '#f97d09',  
    'No': '#02478E'   
}

# Count the occurrences of 'Yes' and 'No' in 'Hidden Bias'
bias_counts = df_n['Hidden Bias'].value_counts()

# Plot the pie chart
fig, ax = plt.subplots()
ax.pie(
    bias_counts,
    labels=bias_counts.index,
    colors=[bias_colors[key] for key in bias_counts.index],
    autopct='%1.1f%%',
    textprops={'color': 'white'}
)

# Set white text and transparent background
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Customize the legend
plt.legend(bias_counts.index, loc="best", facecolor='black', edgecolor='white', fontsize='medium', labelcolor='white')

# Title in white
plt.title('Hidden Bias towards BJP', color='white')
plt.savefig('images/en_ndtv_images/hidden bias.png')

plt.show()

# %% [markdown]
# # **Republic World**

# %%
df_r = pd.read_csv('data/insights/title_desc_cap/en_Republic_World_insights_tdc.csv')

# %%
# Calculate the counts of each target party
target_party_counts = df_r['Target Party'].value_counts()

# Define a threshold for grouping small proportions into "Other"
threshold = 0.02 * target_party_counts.sum()  # 2% threshold
target_party_counts = target_party_counts[target_party_counts >= threshold]
other_count = df_r['Target Party'].value_counts()[df_r['Target Party'].value_counts() < threshold].sum()

# Add the "Other" category if needed
if other_count > 0:
    target_party_counts['Other'] = other_count

# Calculate the proportions
target_party_proportions = target_party_counts / target_party_counts.sum()

# Plot the pie chart
colors = ['#02478E','#f97d09','#167B37','#31CB56','#B02C28']
plt.figure(figsize=(10, 7), facecolor='none')  
plt.pie(
    target_party_proportions,
    labels=target_party_proportions.index,
    autopct='%1.1f%%',
    startangle=140,
    textprops={'color': 'white'} ,
    colors=colors[:len(target_party_proportions)] 
)
plt.title('Party Mentions in the Videos', color='white')  
plt.gca().set_facecolor('none')
plt.savefig('images/RW_images/counts of each party.png')

# %%
import matplotlib.pyplot as plt

# Calculate the total count for each party
party_counts = df_r['Target Party'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_r[df_r['Target Party'].isin(filtered_parties)]

# Group the data by Target Party and Sentiment and get counts
sentiment_counts = filtered_df.groupby(['Target Party', 'Sentiment']).size().unstack(fill_value=0)

# Sort the sentiment counts by the sum of counts for each party
sentiment_counts = sentiment_counts.loc[sentiment_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the sorted stacked horizontal bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
sentiment_counts.plot(kind='barh', stacked=True, ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', (p.get_x() + p.get_width() / 2, p.get_y() + p.get_height() / 2),
                ha='center', va='center', color='white', fontsize=10)

# Set plot title and labels with white color
plt.title('Sentiment Counts for Each Target Party', color='white')
plt.xlabel('Count', color='white')
plt.ylabel('Target Party', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
plt.savefig('images/RW_images/sentiment counts of each party.png')

# Show the plot
plt.show()

# %%
# Calculate the total count for each party
party_counts = df_r['Target Party'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_r[df_r['Target Party'].isin(filtered_parties)]

# Group the data by Target Party and Orientation and get counts
orientation_counts = filtered_df.groupby(['Target Party', 'Orientation']).size().unstack(fill_value=0)

# Sort the orientation counts by the sum of counts for each party
orientation_counts = orientation_counts.loc[orientation_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the grouped bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
orientation_counts.plot(kind='bar', ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_y() + p.get_height() / 2),
                ha='center', va='center', color='white', fontsize=7)

# Set plot title and labels with white color
plt.title('Orientation Counts for Each Target Party', color='white')
plt.xlabel('Target Party', color='white')
plt.ylabel('Count', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/RW_images/orientation counts of each party.png')

# Show the plot
plt.show()

# %%
# Calculate the counts of each alliance
alliance_counts = df_r['Alliance'].value_counts()

# Define a threshold for grouping small proportions into "Other"
threshold = 0.02 * alliance_counts.sum()  # 2% threshold
alliance_counts = alliance_counts[alliance_counts >= threshold]
other_count = df_r['Alliance'].value_counts()[df_r['Alliance'].value_counts() < threshold].sum()

# Add the "Other" category if needed
if other_count > 0:
    alliance_counts['Other'] = other_count

# Calculate the proportions
alliance_proportions = alliance_counts / alliance_counts.sum()

# Plot the pie chart
colors = ['#02478E', '#f97d09', '#B02C28', '#B02C28']
plt.figure(figsize=(10, 7), facecolor='none')
plt.pie(
    alliance_proportions,
    labels=alliance_proportions.index,
    autopct='%1.1f%%',
    startangle=140,
    textprops={'color': 'white'},
    colors=colors[:len(alliance_proportions)]
)
plt.title('Alliance Mentions in the Videos', color='white')
plt.gca().set_facecolor('none')

plt.savefig('images/RW_images/counts of each alliance.png')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the total count for each party
party_counts = df_r['Alliance'].value_counts()

# Define the threshold
threshold = 1  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_r[df_r['Alliance'].isin(filtered_parties)]

# Group the data by Alliance and Sentiment and get counts
sentiment_counts = filtered_df.groupby(['Alliance', 'Sentiment']).size().unstack(fill_value=0)

# Sort the sentiment counts by the sum of counts for each party
sentiment_counts = sentiment_counts.loc[sentiment_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the sorted stacked horizontal bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
sentiment_counts.plot(kind='barh', stacked=True, ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', (p.get_x() + p.get_width() / 2, p.get_y() + p.get_height() / 2),
                ha='center', va='center', color='white', fontsize=10)

# Set plot title and labels with white color
plt.title('Sentiment Counts for Each Alliance', color='white')
plt.xlabel('Count', color='white')
plt.ylabel('Alliance', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/RW_images/sentiment counts of each alliance.png')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the total count for each party
party_counts = df_r['Alliance'].value_counts()

# Define the threshold
threshold = 1  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_r[df_r['Alliance'].isin(filtered_parties)]

# Group the data by Target Party and Orientation and get counts
orientation_counts = filtered_df.groupby(['Alliance', 'Orientation']).size().unstack(fill_value=0)

# Sort the orientation counts by the sum of counts for each party
orientation_counts = orientation_counts.loc[orientation_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the vertical bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
orientation_counts.plot(kind='bar', ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_height() + 0.5),
                ha='center', va='bottom', color='white', fontsize=7)

# Set plot title and labels with white color
plt.title('Orientation Counts for Alliance', color='white')
plt.xlabel('Alliance', color='white')
plt.ylabel('Count', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/RW_images/orientation counts of each alliance.png')

# Show the plot
plt.show()

# %%
# Define thresholds
views_threshold = 150000

# Filter parties above the threshold
filtered_views = df_r.groupby('Target Party')['views'].sum()

# Create 'Others' category for views
views_below_threshold = filtered_views[filtered_views < views_threshold].sum()
filtered_views = filtered_views[filtered_views >= views_threshold]
filtered_views['Others'] = views_below_threshold

# Sort the views in descending order
filtered_views = filtered_views.sort_values(ascending=True)

# Plot the chart
fig, ax = plt.subplots(figsize=(15, 7), facecolor='none')

# Plot total views
ax.barh(filtered_views.index, filtered_views.values, color='coral')
ax.set_xlabel('Total Views', color='white')
ax.set_ylabel('Target Party', color='white')
ax.set_title('Total Views per Target Party', color='white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Annotate the bars with integer counts for views
for i in ax.patches:
    ax.annotate(f'{int(i.get_width())}', (i.get_width() + i.get_x(), i.get_y() + i.get_height() / 2),
                ha='left', va='center', color='white', fontsize=7)

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/RW_images/total view.png')

plt.tight_layout()
plt.show()

# %%
# Ensure the 'publish_date' column is in datetime format
df_r.loc[:, 'publish_date'] = pd.to_datetime(df_r['publish_date'], format='%d-%m-%Y')

# Define custom colors for the parties
party_colors = {
    'BJP': '#f97d09',
    'INC': '#02478E',
    'AAP': '#167B37', 
}

# Function to plot the timeline for a given orientation
def plot_timeline(orientation, title, ax, threshold, party_colors):
    # Filter for rows where Orientation matches the specified orientation
    df_orientation = df_r[df_r['Orientation'] == orientation]

    # Define the threshold and filter out parties below the threshold
    party_counts = df_orientation['Target Party'].value_counts()
    filtered_parties = party_counts[party_counts >= threshold].index
    df_orientation = df_orientation[df_orientation['Target Party'].isin(filtered_parties)]

    # Group the data by publish_date and Target Party to get the count of sentiments
    grouped_df = df_orientation.groupby(['publish_date', 'Target Party']).size().unstack(level=1, fill_value=0)

    # Plot the timeline for each party with custom colors
    colors = [party_colors.get(col, '#333333') for col in grouped_df.columns]
    grouped_df.plot(ax=ax, linestyle='-', color=colors)

    # Set labels with white color
    ax.set_xlabel('Date', color='white')
    ax.set_ylabel('Count', color='white')
    ax.set_title(title, color='white')

    # Set x and y axis tick parameters to white
    ax.tick_params(axis='x', colors='white')
    ax.tick_params(axis='y', colors='white')

    # Set the figure background and axes face color to transparent
    fig.patch.set_alpha(0.0)
    ax.patch.set_alpha(0.0)

    # Set the border color of the plot to white
    ax.spines['top'].set_color('white')
    ax.spines['right'].set_color('white')
    ax.spines['bottom'].set_color('white')
    ax.spines['left'].set_color('white')

# Define thresholds
threshold_supports = 1
threshold_opposes = 15

# Create a plot for 'Supports' and 'Opposes' sentiments side by side
fig, axes = plt.subplots(1, 2, figsize=(15, 7), sharey=True)

# Plot for 'Supports' sentiment
plot_timeline('Supports', 'Timeline of Supportive Sentiments by Party', axes[0], threshold_supports, party_colors)

# Plot for 'Opposes' sentiment
plot_timeline('Opposes', 'Timeline of Opposing Sentiments by Party', axes[1], threshold_opposes, party_colors)

plt.savefig('images/RW_images/timeline sentiment.png')

plt.tight_layout()
plt.show()

# %%
# Define colors for the pie chart
bias_colors = {
    'Yes': '#f97d09',  
    'No': '#02478E'   
}

# Count the occurrences of 'Yes' and 'No' in 'Hidden Bias'
bias_counts = df_r['Hidden Bias'].value_counts()

# Plot the pie chart
fig, ax = plt.subplots()
ax.pie(
    bias_counts,
    labels=bias_counts.index,
    colors=[bias_colors[key] for key in bias_counts.index],
    autopct='%1.1f%%',
    textprops={'color': 'white'}
)

# Set white text and transparent background
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Customize the legend
plt.legend(bias_counts.index, loc="best", facecolor='black', edgecolor='white', fontsize='medium', labelcolor='white')

# Title in white
plt.title('Hidden Bias towards BJP', color='white')

plt.savefig('images/RW_images/hidden bias.png')

plt.show()

# %% [markdown]
# # **Times Now**

# %%
df_t = pd.read_csv("data/insights/title_desc_cap/en_Times_Now_insights_tdc.csv")

# %%
# Calculate the counts of each target party
target_party_counts = df_t['Target Party'].value_counts()

# Define a threshold for grouping small proportions into "Other"
threshold = 0.02 * target_party_counts.sum()  # 2% threshold
target_party_counts = target_party_counts[target_party_counts >= threshold]
other_count = df_t['Target Party'].value_counts()[df_t['Target Party'].value_counts() < threshold].sum()

# Add the "Other" category if needed
if other_count > 0:
    target_party_counts['Other'] = other_count

# Calculate the proportions
target_party_proportions = target_party_counts / target_party_counts.sum()

# Plot the pie chart
colors = ['#f97d09','#02478E','#167B37','#B02C28']
plt.figure(figsize=(10, 7), facecolor='none')  
plt.pie(
    target_party_proportions,
    labels=target_party_proportions.index,
    autopct='%1.1f%%',
    startangle=140,
    textprops={'color': 'white'} ,
    colors=colors[:len(target_party_proportions)] 
)
plt.title('Party Mentions in the Videos', color='white')  
plt.gca().set_facecolor('none')

plt.savefig('images/TN_images/counts of each party.png')

# %%
# Calculate the total count for each party
party_counts = df_t['Target Party'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_t[df_t['Target Party'].isin(filtered_parties)]

# Group the data by Target Party and Sentiment and get counts
sentiment_counts = filtered_df.groupby(['Target Party', 'Sentiment']).size().unstack(fill_value=0)

# Sort the sentiment counts by the sum of counts for each party
sentiment_counts = sentiment_counts.loc[sentiment_counts.sum(axis=1).sort_values(ascending=False).index]

# to get neutral on top
sentiment_counts = sentiment_counts[['Negative', 'Positive', 'Neutral']]

# Plot the sorted stacked bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
sentiment_counts.plot(kind='bar', stacked=True, ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_y() + p.get_height() / 2),
                ha='center', va='center', color='white', fontsize=7)

# Set plot title and labels with white color
plt.title('Sentiment Counts for Each Target Party', color='white')
plt.xlabel('Target Party', color='white')
plt.ylabel('Count', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/TN_images/sentiment counts of each party.png')

# Show the plot
plt.show()

# %%
# Calculate the total count for each party
party_counts = df_t['Target Party'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_t[df_t['Target Party'].isin(filtered_parties)]

# Group the data by Target Party and Orientation and get counts
orientation_counts = filtered_df.groupby(['Target Party', 'Orientation']).size().unstack(fill_value=0)

# Sort the orientation counts by the sum of counts for each party
orientation_counts = orientation_counts.loc[orientation_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the grouped bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
orientation_counts.plot(kind='bar', ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_y() + p.get_height() / 2),
                ha='center', va='center', color='white', fontsize=7)

# Set plot title and labels with white color
plt.title('Orientation Counts for Each Target Party', color='white')
plt.xlabel('Target Party', color='white')
plt.ylabel('Count', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/TN_images/orientation counts of each party.png')

# Show the plot
plt.show()

# %%
# Calculate the counts of each alliance
alliance_counts = df_t['Alliance'].value_counts()

# Define a threshold for grouping small proportions into "Other"
threshold = 0.02 * alliance_counts.sum()  # 2% threshold
alliance_counts = alliance_counts[alliance_counts >= threshold]
other_count = df_t['Alliance'].value_counts()[df_t['Alliance'].value_counts() < threshold].sum()

# Add the "Other" category if needed
if other_count > 0:
    alliance_counts['Other'] = other_count

# Calculate the proportions
alliance_proportions = alliance_counts / alliance_counts.sum()

# Plot the pie chart
colors = ['#02478E', '#f97d09', '#B02C28', '#B02C28']
plt.figure(figsize=(10, 7), facecolor='none')
plt.pie(
    alliance_proportions,
    labels=alliance_proportions.index,
    autopct='%1.1f%%',
    startangle=140,
    textprops={'color': 'white'},
    colors=colors[:len(alliance_proportions)]
)
plt.title('Alliance Mentions in the Videos', color='white')
plt.gca().set_facecolor('none')

plt.savefig('images/TN_images/counts of each alliance.png')

# Show the plot
plt.show()

# %%
# Calculate the total count for each party
party_counts = df_t['Alliance'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_t[df_t['Alliance'].isin(filtered_parties)]

# Group the data by Target Party and Orientation and get counts
orientation_counts = filtered_df.groupby(['Alliance', 'Orientation']).size().unstack(fill_value=0)

# Sort the orientation counts by the sum of counts for each party
orientation_counts = orientation_counts.loc[orientation_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the horizontal bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
orientation_counts.plot(kind='barh', ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', (p.get_width() + p.get_x(), p.get_y() + p.get_height() / 2),
                ha='left', va='center', color='white', fontsize=7)

# Set plot title and labels with white color
plt.title('Orientation Counts for Alliance', color='white')
plt.xlabel('Count', color='white')
plt.ylabel('Alliance', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/TN_images/orientation counts of each alliance.png')

# Show the plot
plt.show()

# %%
# Define thresholds
views_threshold = 150000

# Filter parties above the threshold
filtered_views = df_t.groupby('Target Party')['views'].sum()

# Create 'Others' category for views
views_below_threshold = filtered_views[filtered_views < views_threshold].sum()
filtered_views = filtered_views[filtered_views >= views_threshold]
filtered_views['Others'] = views_below_threshold

# Sort the views in descending order
filtered_views = filtered_views.sort_values(ascending=True)

# Plot the chart
fig, ax = plt.subplots(figsize=(15, 7), facecolor='none')

# Plot total views
ax.barh(filtered_views.index, filtered_views.values, color='coral')
ax.set_xlabel('Total Views', color='white')
ax.set_ylabel('Target Party', color='white')
ax.set_title('Total Views per Target Party', color='white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Annotate the bars with integer counts for views
for i in ax.patches:
    ax.annotate(f'{int(i.get_width())}', (i.get_width() + i.get_x(), i.get_y() + i.get_height() / 2),
                ha='left', va='center', color='white', fontsize=7)

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.tight_layout()

plt.savefig('images/TN_images/total view.png')

plt.show()

# %%
import matplotlib.dates as mdates

# Ensure the 'publish_date' column is in datetime format
df_t.loc[:, 'publish_date'] = pd.to_datetime(df_t['publish_date'], format='%d-%m-%Y')

# Define custom colors for the parties
party_colors = {
    'BJP': '#f97d09',
    'INC': '#02478E',
    'AAP': '#167B37', 
}

# Function to plot the timeline for a given orientation
def plot_timeline(orientation, title, ax, threshold, party_colors):
    # Filter for rows where Orientation matches the specified orientation
    df_orientation = df_t[df_t['Orientation'] == orientation]

    # Define the threshold and filter out parties below the threshold
    party_counts = df_orientation['Target Party'].value_counts()
    filtered_parties = party_counts[party_counts >= threshold].index
    df_orientation = df_orientation[df_orientation['Target Party'].isin(filtered_parties)]

    # Group the data by publish_date and Target Party to get the count of sentiments
    grouped_df = df_orientation.groupby(['publish_date', 'Target Party']).size().unstack(level=1, fill_value=0)

    # Plot the timeline for each party with custom colors
    colors = [party_colors.get(col, '#333333') for col in grouped_df.columns]
    grouped_df.plot(ax=ax, linestyle='-', color=colors)

    # Set labels with white color
    ax.set_xlabel('Date', color='white')
    ax.set_ylabel('Count', color='white')
    ax.set_title(title, color='white')

    # Set x and y axis tick parameters to white
    ax.tick_params(axis='x', colors='white')
    ax.tick_params(axis='y', colors='white')

    # Set the figure background and axes face color to transparent
    fig.patch.set_alpha(0.0)
    ax.patch.set_alpha(0.0)

    # Set the border color of the plot to white
    ax.spines['top'].set_color('white')
    ax.spines['right'].set_color('white')
    ax.spines['bottom'].set_color('white')
    ax.spines['left'].set_color('white')

    # Format x-axis dates dynamically
    date_range = df_orientation['publish_date'].max() - df_orientation['publish_date'].min()
    if date_range.days > 90:
        ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
    else:
        ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=1))
    
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# Define thresholds
threshold_supports = 5
threshold_opposes = 20

# Create a plot for 'Supports' and 'Opposes' sentiments side by side
fig, axes = plt.subplots(1, 2, figsize=(14, 7), sharey=True)

# Plot for 'Supports' sentiment
plot_timeline('Supports', 'Timeline of Supportive Sentiments by Party', axes[0], threshold_supports, party_colors)

# Plot for 'Opposes' sentiment
plot_timeline('Opposes', 'Timeline of Opposing Sentiments by Party', axes[1], threshold_opposes, party_colors)

plt.tight_layout()

plt.savefig('images/TN_images/timeline sentiment.png')

plt.show()

# %%
# Define colors for the pie chart
bias_colors = {
    'Yes': '#f97d09',  
    'No': '#02478E'   
}

# Count the occurrences of 'Yes' and 'No' in 'Hidden Bias'
bias_counts = df_t['Hidden Bias'].value_counts()

# Plot the pie chart
fig, ax = plt.subplots()
ax.pie(
    bias_counts,
    labels=bias_counts.index,
    colors=[bias_colors[key] for key in bias_counts.index],
    autopct='%1.1f%%',
    textprops={'color': 'white'}
)

# Set white text and transparent background
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Customize the legend
plt.legend(bias_counts.index, loc="best", facecolor='black', edgecolor='white', fontsize='medium', labelcolor='white')

# Title in white
plt.title('Hidden Bias towards BJP', color='white')

plt.savefig('images/TN_images/hidden bias.png')

plt.show()

# %% [markdown]
# **NDTV India**

# %%
df_n = pd.read_csv('data/insights/title_desc_cap/hi_ndtv_india_insights_tdc.csv')

# %%
# Calculate the counts of each target party
target_party_counts = df_n['Target Party'].value_counts()

# Define a threshold for grouping small proportions into "Other"
threshold = 0.02 * target_party_counts.sum()  # 2% threshold
target_party_counts = target_party_counts[target_party_counts >= threshold]
other_count = df_n['Target Party'].value_counts()[df_n['Target Party'].value_counts() < threshold].sum()

# Add the "Other" category if needed
if other_count > 0:
    target_party_counts['Other'] = other_count

# Calculate the proportions
target_party_proportions = target_party_counts / target_party_counts.sum()

# Plot the pie chart
colors = ['#f97d09','#02478E','#167B37','#B02C28']
plt.figure(figsize=(10, 7), facecolor='none')  
plt.pie(
    target_party_proportions,
    labels=target_party_proportions.index,
    autopct='%1.1f%%',
    startangle=140,
    textprops={'color': 'white'} ,
    colors=colors[:len(target_party_proportions)] 
)
plt.title('Party Mentions in the Videos', color='white')  
plt.gca().set_facecolor('none')
plt.savefig('images/ndtv_images/counts of each party.png')

# %%
import matplotlib.pyplot as plt

# Calculate the total count for each party
party_counts = df_n['Target Party'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_n[df_n['Target Party'].isin(filtered_parties)]

# Group the data by Target Party and Sentiment and get counts
sentiment_counts = filtered_df.groupby(['Target Party', 'Sentiment']).size().unstack(fill_value=0)

# Sort the sentiment counts by the sum of counts for each party
sentiment_counts = sentiment_counts.loc[sentiment_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the sorted stacked horizontal bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
sentiment_counts.plot(kind='barh', stacked=True, ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', (p.get_x() + p.get_width() / 2, p.get_y() + p.get_height() / 2),
                ha='center', va='center', color='white', fontsize=10)

# Set plot title and labels with white color
plt.title('Sentiment Counts for Each Target Party', color='white')
plt.xlabel('Count', color='white')
plt.ylabel('Target Party', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
plt.savefig('images/ndtv_images/sentiment counts of each party.png')
# Show the plot
plt.show()

# %%
# Calculate the total count for each party
party_counts = df_n['Target Party'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_n[df_n['Target Party'].isin(filtered_parties)]

# Group the data by Target Party and Orientation and get counts
orientation_counts = filtered_df.groupby(['Target Party', 'Orientation']).size().unstack(fill_value=0)

# Sort the orientation counts by the sum of counts for each party
orientation_counts = orientation_counts.loc[orientation_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the grouped bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
orientation_counts.plot(kind='bar', ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_y() + p.get_height() / 2),
                ha='center', va='center', color='white', fontsize=7)

# Set plot title and labels with white color
plt.title('Orientation Counts for Each Target Party', color='white')
plt.xlabel('Target Party', color='white')
plt.ylabel('Count', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.savefig('images/ndtv_images/orientation counts of each party.png')
# Show the plot
plt.show()

# %%
# Calculate the counts of each alliance
alliance_counts = df_n['Alliance'].value_counts()

# Define a threshold for grouping small proportions into "Other"
threshold = 0.02 * alliance_counts.sum()  # 2% threshold
alliance_counts = alliance_counts[alliance_counts >= threshold]
other_count = df_n['Alliance'].value_counts()[df_n['Alliance'].value_counts() < threshold].sum()

# Add the "Other" category if needed
if other_count > 0:
    alliance_counts['Other'] = other_count

# Calculate the proportions
alliance_proportions = alliance_counts / alliance_counts.sum()

# Plot the pie chart
colors = ['#f97d09', '#02478E', '#B02C28', '#B02C28']
plt.figure(figsize=(10, 7), facecolor='none')
plt.pie(
    alliance_proportions,
    labels=alliance_proportions.index,
    autopct='%1.1f%%',
    startangle=140,
    textprops={'color': 'white'},
    colors=colors[:len(alliance_proportions)]
)
plt.title('Alliance Mentions in the Videos', color='white')
plt.gca().set_facecolor('none')
plt.savefig('images/ndtv_images/counts of each alliance.png')
# Show the plot
plt.show()

# %%
# Calculate the total count for each party
party_counts = df_n['Alliance'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_n[df_n['Alliance'].isin(filtered_parties)]

# Group the data by Alliance and Sentiment and get counts
sentiment_counts = filtered_df.groupby(['Alliance', 'Sentiment']).size().unstack(fill_value=0)

# Sort the sentiment counts by the sum of counts for each party
sentiment_counts = sentiment_counts.loc[sentiment_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the sorted stacked horizontal bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
sentiment_counts.plot(kind='barh', stacked=True, ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', (p.get_x() + p.get_width() / 2, p.get_y() + p.get_height() / 2),
                ha='center', va='center', color='white', fontsize=10)

# Set plot title and labels with white color
plt.title('Sentiment Counts for Each Alliance', color='white')
plt.xlabel('Count', color='white')
plt.ylabel('Alliance', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
plt.savefig('images/ndtv_images/sentiment counts of each alliance.png')
# Show the plot
plt.show()

# %%
# Calculate the total count for each party
party_counts = df_n['Alliance'].value_counts()

# Define the threshold
threshold = 10  # Adjust as needed

# Filter out parties below the threshold
filtered_parties = party_counts[party_counts >= threshold].index
filtered_df = df_n[df_n['Alliance'].isin(filtered_parties)]

# Group the data by Target Party and Orientation and get counts
orientation_counts = filtered_df.groupby(['Alliance', 'Orientation']).size().unstack(fill_value=0)

# Sort the orientation counts by the sum of counts for each party
orientation_counts = orientation_counts.loc[orientation_counts.sum(axis=1).sort_values(ascending=False).index]

# Plot the vertical bar chart
fig, ax = plt.subplots(figsize=(10, 7), facecolor='none')
orientation_counts.plot(kind='bar', ax=ax)

# Annotate the bars with integer counts
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_height() + 0.5),
                ha='center', va='bottom', color='white', fontsize=7)

# Set plot title and labels with white color
plt.title('Orientation Counts for Alliance', color='white')
plt.xlabel('Alliance', color='white')
plt.ylabel('Count', color='white')

# Set x and y axis tick parameters to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Set the border color of the plot to white
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
plt.savefig('images/ndtv_images/orientation counts of each alliance.png')
# Show the plot
plt.show()

# %%
# Define thresholds
views_threshold = 150000

# Filter parties above the threshold
filtered_views = df_n.groupby('Target Party')['views'].sum()

# Create 'Others' category for views
views_below_threshold = filtered_views[filtered_views < views_threshold].sum()
filtered_views = filtered_views[filtered_views >= views_threshold]
filtered_views['Others'] = views_below_threshold

# Sort the views in descending order
filtered_views = filtered_views.sort_values(ascending=True)

# Plot the chart
fig, ax = plt.subplots(figsize=(15, 7), facecolor='none')

# Plot total views
ax.barh(filtered_views.index, filtered_views.values, color='coral')
ax.set_xlabel('Total Views', color='white')
ax.set_ylabel('Target Party', color='white')
ax.set_title('Total Views per Target Party', color='white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Annotate the bars with integer counts for views
for i in ax.patches:
    ax.annotate(f'{int(i.get_width())}', (i.get_width() + i.get_x(), i.get_y() + i.get_height() / 2),
                ha='left', va='center', color='white', fontsize=7)

# Set the figure background and axes face color to transparent
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')

plt.tight_layout()
plt.savefig('images/ndtv_images/total view.png')
plt.show()

# %%
# Ensure the 'publish_date' column is in datetime format
# df_n.loc[:, 'publish_date'] = pd.to_datetime(df_n['publish_date'], format='%d-%m-%Y')
# Convert 'publish_date' to datetime format with automatic inference for mixed formats
df_n['publish_date'] = pd.to_datetime(df_n['publish_date'], format='mixed', dayfirst=True)


# Define custom colors for the parties
party_colors = {
    'BJP': '#f97d09',
    'INC': '#02478E',
    'AAP': '#167B37', 
}

# Function to plot the timeline for a given orientation
def plot_timeline(orientation, title, ax, threshold, party_colors):
    # Filter for rows where Orientation matches the specified orientation
    df_orientation = df_n[df_n['Orientation'] == orientation]

    # Define the threshold and filter out parties below the threshold
    party_counts = df_orientation['Target Party'].value_counts()
    filtered_parties = party_counts[party_counts >= threshold].index
    df_orientation = df_orientation[df_orientation['Target Party'].isin(filtered_parties)]

    # Group the data by publish_date and Target Party to get the count of sentiments
    grouped_df = df_orientation.groupby(['publish_date', 'Target Party']).size().unstack(level=1, fill_value=0)
    
    # Plot the timeline for each party with custom colors
    colors = [party_colors.get(col, '#333333') for col in grouped_df.columns]
    grouped_df.plot(ax=ax, linestyle='-', color=colors)

    # Set labels with white color
    ax.set_xlabel('Date', color='white')
    ax.set_ylabel('Count', color='white')
    ax.set_title(title, color='white')

    # Set x and y axis tick parameters to white
    ax.tick_params(axis='x', colors='white')
    ax.tick_params(axis='y', colors='white')

    # Set the figure background and axes face color to transparent
    fig.patch.set_alpha(0.0)
    ax.patch.set_alpha(0.0)
    
    # Set the border color of the plot to white
    ax.spines['top'].set_color('white')
    ax.spines['right'].set_color('white')
    ax.spines['bottom'].set_color('white')
    ax.spines['left'].set_color('white')

# Define thresholds
threshold_supports = 10
threshold_opposes = 30

# Create a plot for 'Supports' and 'Opposes' sentiments side by side
fig, axes = plt.subplots(1, 2, figsize=(15, 7), sharey=True)

# Plot for 'Supports' sentiment
plot_timeline('Supports', 'Timeline of Supportive Sentiments by Party', axes[0], threshold_supports, party_colors)

# Plot for 'Opposes' sentiment
plot_timeline('Opposes', 'Timeline of Opposing Sentiments by Party', axes[1], threshold_opposes, party_colors)


plt.tight_layout()
plt.savefig('images/ndtv_images/timeline sentiment.png')
plt.show()

# %%
# Define colors for the pie chart
bias_colors = {
    'Yes': '#f97d09',  
    'No': '#02478E'   
}

# Count the occurrences of 'Yes' and 'No' in 'Hidden Bias'
bias_counts = df_n['Hidden Bias'].value_counts()

# Plot the pie chart
fig, ax = plt.subplots()
ax.pie(
    bias_counts,
    labels=bias_counts.index,
    colors=[bias_colors[key] for key in bias_counts.index],
    autopct='%1.1f%%',
    textprops={'color': 'white'}
)

# Set white text and transparent background
fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

# Customize the legend
plt.legend(bias_counts.index, loc="best", facecolor='black', edgecolor='white', fontsize='medium', labelcolor='white')

# Title in white
plt.title('Hidden Bias towards BJP', color='white')
plt.savefig('images/ndtv_images/hidden bias.png')

plt.show()

# %% [markdown]
# # **Comparative Bias**

# %%
# Create a list of dataframes to plot
dfs = [df_n, df_r, df_t]  # Replace with your actual DataFrames
titles = ['DF1', 'DF2', 'DF3']  # Optional titles for reference

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(24, 7), sharey=True, facecolor='none')

# Iterate over dataframes and axes to plot each dataframe
for df, ax, title in zip(dfs, axes, titles):
    # Calculate the total count for each party
    party_counts = df['Target Party'].value_counts()

    # Define the threshold
    threshold = 10  # Adjust as needed

    # Filter out parties below the threshold
    filtered_parties = party_counts[party_counts >= threshold].index
    filtered_df = df[df['Target Party'].isin(filtered_parties)]

    # Group the data by Target Party and Orientation and get counts
    orientation_counts = filtered_df.groupby(['Target Party', 'Orientation']).size().unstack(fill_value=0)

    # Sort the orientation counts by the sum of counts for each party
    orientation_counts = orientation_counts.loc[orientation_counts.sum(axis=1).sort_values(ascending=False).index]

    # Plot the grouped bar chart
    orientation_counts.plot(kind='bar', ax=ax)

    # Annotate the bars with integer counts
    for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_y() + p.get_height() / 2),
                    ha='center', va='center', color='white', fontsize=7)

    # Set labels with white color
    ax.set_xlabel('Target Party', color='white')
    ax.set_ylabel('Count', color='white')

    # Set x and y axis tick parameters to white
    ax.tick_params(axis='x', colors='white')
    ax.tick_params(axis='y', colors='white')

    # Set the figure background and axes face color to transparent
    fig.patch.set_alpha(0.0)
    ax.patch.set_alpha(0.0)

    # Set the border color of the plot to white
    ax.spines['top'].set_color('white')
    ax.spines['right'].set_color('white')
    ax.spines['bottom'].set_color('white')
    ax.spines['left'].set_color('white')

# Remove titles if not needed
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Hidden Bias**
